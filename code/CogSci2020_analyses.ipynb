# %% [markdown]
# # CogSci 2020 paper -- Analyses
#
# This notebook produces the analyses in our paper "Birds and Words: Exploring environmental influences on folk categorization".

# %%
# load libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import seaborn as sns

# some useful functions
def get_birdcounts(ebd_data):
	# read ebird count and name data
	bird_counts = {}

	science_name = list(ebd_data['SCIENTIFIC NAME'])

	i=0
	for bird_name in science_name:
		if bird_name in bird_counts.keys():
			bird_counts[bird_name] +=1
		else:
			bird_counts[bird_name] = 1

		i+=1

	return bird_counts


def get_basiclevel(zapotec_data):
	bird_sci2basic_names = {}

	basic_name = list(zapotec_data['folk_generic'])
	science_name = list(zapotec_data['species'])

	i=0
	for bird_name in science_name:
		bird_sci2basic_names[bird_name] = basic_name[i]
		i+=1

	return bird_sci2basic_names

def get_terminallevel(zapotec_data):
	bird_sci2terminal_names = {}

	terminal_name = list(zapotec_data['folk_specific'])
	science_name = list(zapotec_data['species'])

	i=0
	for bird_name in science_name:
		if bird_name in bird_sci2terminal_names.keys():
			bird_sci2terminal_names[bird_name].append(terminal_name[i])
		else:
			bird_sci2terminal_names[bird_name] = []
			bird_sci2terminal_names[bird_name].append(terminal_name[i])
		i+=1

	return bird_sci2terminal_names
# Out:
# /Users/josh/miniconda2/envs/py3test/lib/python3.6/site-packages/scipy/__init__.py:115: UserWarning: Numpy 1.13.3 or above is required for this version of scipy (detected version 1.12.1)
#   UserWarning)

# %% [markdown]
# ## Load datasets
# Here, we incorporate the following datasets ...
#
# ### Frequency data
# Here we use eBird

# %%
# load ebird data
ebd_data = pd.read_csv('./data/ebird_MX-OAX_cogsci_clean.csv')
# get bird counts, index by species name
bird_counts = get_birdcounts(ebd_data)

# %% [markdown]
# ### Naming data
# We have precompiled this into a single dataframe (df) for the purposes of replicating these analyses.

# %%
# read full Zapotec data, including data on non-Zapotec birds
zapotec_data_all = pd.read_csv('./data/df_zapotec_fullfeats_cogsci2020.csv')
# make a df of only Zapotec data
zapotec_data_only = zapotec_data_all[zapotec_data_all['folk_generic'].notna()] 

basic_levels = get_basiclevel(zapotec_data_only)
basic_level_names = list(set(zapotec_data_only['folk_generic']))
terminal_names = get_terminallevel(zapotec_data_only)

# %%
zapotec_data_only
# Out:
#                         species                  common_name     mass  freq  \
# 0            Myiarchus nuttingi         Nutting's Flycatcher    23.00  1903
# 1            Sayornis nigricans                 Black Phoebe    18.63  1918
# 2               Amazilia rutila         Cinnamon Hummingbird     5.24     0
# 3           Tyrannus vociferans            Cassin's Kingbird    45.60  5119
# 4          Patagioenas fasciata           Band-tailed Pigeon   366.30   927
# 5             Empidonax affinis              Pine Flycatcher    11.30   393
# 6              Buteo brachyurus            Short-tailed Hawk   496.01  1314
# 7          Aeronautes saxatalis         White-throated Swift    32.10   259
# 8            Amazilia beryllina        Berylline Hummingbird     4.50  6678
# 9            Leiothlypis celata       Orange-crowned Warbler     9.19     0
# 10           Turdus migratorius               American Robin    78.50  1542
# 11               Trogon elegans               Elegant Trogon    70.89   284
# 12             Poecile sclateri            Mexican Chickadee    10.09  1172
# 13        Cardellina rubrifrons            Red-faced Warbler     8.10   577
# 14                  Pipilo ocai              Collared Towhee    60.95  1116
# 15             Trogon mexicanus              Mountain Trogon    71.00  1561
# 16               Vireo plumbeus              Plumbeous Vireo    16.40   683
# 17          Quiscalus mexicanus         Great-tailed Grackle   160.47  6954
# 18       Melanotis caerulescens             Blue Mockingbird    61.57  4343
# 19               Aythya affinis                 Lesser Scaup   819.45   258
# 20          Polioptila caerulea        Blue-gray Gnatcatcher     5.80  6898
# 21     Petrochelidon pyrrhonota                Cliff Swallow    21.60     0
# 22         Eremophila alpestris                  Horned Lark    33.33    80
# 23          Bombycilla cedrorum                Cedar Waxwing    31.58   533
# 24            Cypseloides niger                  Black Swift    39.67   236
# 25            Sarcoramphus papa                 King Vulture  3400.00    49
# 26          Setophaga townsendi           Townsend's Warbler     8.84  3787
# 27         Haemorhous mexicanus                  House Finch    21.40  7991
# 28             Junco phaeonotus            Yellow-eyed Junco    20.40  2155
# 29    Pheucticus melanocephalus        Black-headed Grosbeak    47.13  2627
# ..                          ...                          ...      ...   ...
# 123             Icterus wagleri          Black-vented Oriole    41.80  5262
# 124             Ciccaba virgata                  Mottled Owl   283.97   338
# 125         Hylocharis leucotis      White-eared Hummingbird     3.39  2753
# 126              Spinus notatus          Black-headed Siskin    10.90   664
# 127        Setophaga nigrescens  Black-throated Gray Warbler     8.70     0
# 128            Bubo virginianus             Great Horned Owl  1575.70   145
# 129       Toxostoma curvirostre        Curve-billed Thrasher    80.54  5046
# 130            Zenaida macroura                Mourning Dove   118.93  1936
# 131      Empidonax occidentalis       Cordilleran Flycatcher    11.60   967
# 132        Ortalis poliocephala      West Mexican Chachalaca   760.00  2653
# 133             Hirundo rustica                 Barn Swallow    17.91  1206
# 134  Lepidocolaptes leucogaster    White-striped Woodcreeper    36.00   380
# 135     Leiothlypis ruficapilla            Nashville Warbler     8.09     0
# 136           Passer domesticus                House Sparrow    26.51  4624
# 137         Cyanocitta stelleri                Steller's Jay   128.00  2302
# 138            Glaucidium gnoma           Northern Pygmy-Owl    61.25   413
# 139               Sayornis saya                 Say's Phoebe    20.90   302
# 140         Melospiza lincolnii            Lincoln's Sparrow    16.60  1733
# 141                 Anas crecca            Green-winged Teal   341.89   370
# 142             Mniotilta varia      Black-and-white Warbler    10.90  2991
# 143           Mimus polyglottos         Northern Mockingbird    48.50  1678
# 144          Oxyura jamaicensis                   Ruddy Duck   608.15   690
# 145            Caracara plancus            Southern Caracara  1078.62     0
# 146         Cyrtonyx montezumae              Montezuma Quail   185.38    18
# 147                Corvus corax                 Common Raven   927.97  2006
# 148      Eupsittula canicularis      Orange-fronted Parakeet    85.00     0
# 149          Accipiter striatus           Sharp-shinned Hawk   130.59   862
# 150     Mitrephanes phaeocercus            Tufted Flycatcher     8.59  1776
# 151             Eugenes fulgens         Rivoli's Hummingbird     8.00  1642
# 152           Selasphorus rufus           Rufous Hummingbird     3.50   360
#
#             folk_generic        folk_specific  \
# 0          mguîn̲-rchǔup        mguîn̲-rchǔup
# 1           mguîn̲-guiùu         mguîn̲-guiùu
# 2                 dzǐn̲g               dzǐn̲g
# 3               cùchguêr             cùchguêr
# 4                  pàlôm            pàlôm-dán
# 5                    wǐt                  wǐt
# 6                    msì                  msì
# 7                 xlútsǐ          xlútsǐ-ngǎs
# 8                 dzǐn̲g               dzǐn̲g
# 9                    wǐt                  wǐt
# 10                  miân                 miân
# 11              chòo-dzê             chòo-dzê
# 12          mguîn̲-pàyâs         mguîn̲-pàyâs
# 13                   wǐt                  wǐt
# 14               chùubây              chùubây
# 15               mèr-dán              mèr-dán
# 16                 mtsùu                mtsùu
# 17            mguîn̲-bǒo           mguîn̲-bǒo
# 18           mæ̀cw-guiùu          mæ̀cw-guiùu
# 19                   bǎd             bǎd-guìx
# 20                   dìx                  dìx
# 21                xlútsǐ        xlútsǐ-nquǐts
# 22         mguîn̲-ló-liù        mguîn̲-ló-liù
# 23           mguîn̲-bæ̀d          mguîn̲-bæ̀d
# 24                xlútsǐ          xlútsǐ-ngǎs
# 25                  pěch          pěch-msìdòo
# 26                 yěets           yěets-pînt
# 27                 mguěy                mguěy
# 28   mguîn̲-x-còl-nquǐts  mguîn̲-x-còl-nquǐts
# 29                 mguěy    mguěy-guièe-pchôg
# ..                   ...                  ...
# 123                mguěy    mguěy-guièe-pchôg
# 124                 dǎm̲             dǎm̲-yêt
# 125               dzǐn̲g    dzǐn̲g-dán-yǎ-guì
# 126                yěets            yěets-dán
# 127                  wǐt                  wǐt
# 128                 dǎm̲                 dǎm̲
# 129              mquièts              mquièts
# 130                 mézh                 mézh
# 131                  wǐt                  wǐt
# 132            chìchàlác            chìchàlác
# 133               xlútsǐ        xlútsǐ-nquǐts
# 134              ârbìtrò              ârbìtrò
# 135       mguîn̲-tsíríic       mguîn̲-tsíríic
# 136         mguîn̲-mòlîn         mguîn̲-mòlîn
# 137                cuǐl̲            cuǐl̲-guì
# 138                 mquí                 mquí
# 139             cùchguêr         xín-cùchguêr
# 140                mtsùu                mtsùu
# 141                  bǎd             bǎd-guìx
# 142                  wǐt                  wǐt
# 143              mquièts              mquièts
# 144                  bǎd             bǎd-guìx
# 145     mguîn̲-rlæ̌-dzìt     mguîn̲-rlæ̌-dzìt
# 146                  mtǒ                  mtǒ
# 147                  ngǎ                  ngǎ
# 148               pèrícw               pèrícw
# 149                  msì              msì-lâg
# 150                  wǐt              wǐt-dán
# 151               dzǐn̲g               dzǐn̲g
# 152               dzǐn̲g               dzǐn̲g
#
#                                         clements_group  prototype  \
# 0    Tyrant Flycatchers: Pewees, Kingbirds, and Allies        0.0
# 1    Tyrant Flycatchers: Pewees, Kingbirds, and Allies        0.0
# 2                                         Hummingbirds        0.0
# 3    Tyrant Flycatchers: Pewees, Kingbirds, and Allies        0.0
# 4                                    Pigeons and Doves        0.0
# 5    Tyrant Flycatchers: Pewees, Kingbirds, and Allies        0.0
# 6                          Vultures, Hawks, and Allies        0.0
# 7                                               Swifts        0.0
# 8                                         Hummingbirds        0.0
# 9                                        Wood-Warblers        0.0
# 10                                            Thrushes        0.0
# 11                                Trogons and Quetzals        0.0
# 12                       Tits, Chickadees, and Titmice        0.0
# 13                                       Wood-Warblers        0.0
# 14                                  New World Sparrows        0.0
# 15                                Trogons and Quetzals        0.0
# 16                                              Vireos        0.0
# 17                                          Blackbirds        0.0
# 18               Catbirds, Mockingbirds, and Thrashers        0.0
# 19                                           Waterfowl        0.0
# 20                                        Gnatcatchers        0.0
# 21                                Martins and Swallows        0.0
# 22                                               Larks        0.0
# 23                                            Waxwings        0.0
# 24                                              Swifts        0.0
# 25                         Vultures, Hawks, and Allies        0.0
# 26                                       Wood-Warblers        0.0
# 27                      Finches, Euphonias, and Allies        1.0
# 28                                  New World Sparrows        0.0
# 29                    Cardinals, Grosbeaks, and Allies        0.0
# ..                                                 ...        ...
# 123                                         Blackbirds        0.0
# 124                                               Owls        0.0
# 125                                       Hummingbirds        0.0
# 126                     Finches, Euphonias, and Allies        0.0
# 127                                      Wood-Warblers        0.0
# 128                                               Owls        1.0
# 129              Catbirds, Mockingbirds, and Thrashers        0.0
# 130                                  Pigeons and Doves        0.0
# 131  Tyrant Flycatchers: Pewees, Kingbirds, and Allies        0.0
# 132                  Chachalacas, Guans, and Curassows        0.0
# 133                               Martins and Swallows        0.0
# 134                                       Woodcreepers        0.0
# 135                                      Wood-Warblers        0.0
# 136                                 Old World Sparrows        0.0
# 137                   Jays, Magpies, Crows, and Ravens        0.0
# 138                                               Owls        0.0
# 139  Tyrant Flycatchers: Pewees, Kingbirds, and Allies        0.0
# 140                                 New World Sparrows        0.0
# 141                                          Waterfowl        0.0
# 142                                      Wood-Warblers        0.0
# 143              Catbirds, Mockingbirds, and Thrashers        0.0
# 144                                          Waterfowl        0.0
# 145                              Falcons and Caracaras        0.0
# 146                          Grouse, Quail, and Allies        0.0
# 147                   Jays, Magpies, Crows, and Ravens        0.0
# 148                     Parrots, Parakeets, and Allies        0.0
# 149                        Vultures, Hawks, and Allies        0.0
# 150  Tyrant Flycatchers: Pewees, Kingbirds, and Allies        0.0
# 151                                       Hummingbirds        0.0
# 152                                       Hummingbirds        0.0
#
#      group_size_folk_generics  group_size_folk_specific  ...       PC8  \
# 0                         2.0                       2.0  ...  0.018530
# 1                         1.0                       1.0  ...  0.052137
# 2                        14.0                      10.0  ... -0.155520
# 3                         4.0                       3.0  ...  0.012510
# 4                         2.0                       1.0  ...  0.182247
# 5                        12.0                      11.0  ...  0.036864
# 6                         7.0                       3.0  ...  0.010936
# 7                         7.0                       3.0  ... -0.330202
# 8                        14.0                      10.0  ... -0.142728
# 9                        12.0                      11.0  ... -0.092296
# 10                        1.0                       1.0  ... -0.099631
# 11                        1.0                       1.0  ... -0.026479
# 12                        2.0                       2.0  ...  0.020597
# 13                       12.0                      11.0  ... -0.051677
# 14                        1.0                       1.0  ... -0.028757
# 15                        1.0                       1.0  ... -0.032803
# 16                        8.0                       8.0  ... -0.021628
# 17                        1.0                       1.0  ... -0.089889
# 18                        1.0                       1.0  ...  0.078435
# 19                        7.0                       5.0  ... -0.110502
# 20                        1.0                       1.0  ... -0.032351
# 21                        7.0                       4.0  ... -0.049789
# 22                        1.0                       1.0  ... -0.134777
# 23                        1.0                       1.0  ... -0.037392
# 24                        7.0                       3.0  ... -0.405144
# 25                        3.0                       1.0  ... -0.041087
# 26                        3.0                       1.0  ... -0.105239
# 27                        4.0                       2.0  ... -0.111062
# 28                        1.0                       1.0  ... -0.059695
# 29                        4.0                       2.0  ... -0.060998
# ..                        ...                       ...  ...       ...
# 123                       4.0                       2.0  ...  0.021188
# 124                       3.0                       2.0  ...  0.103169
# 125                      14.0                       1.0  ... -0.078023
# 126                       3.0                       1.0  ... -0.048554
# 127                      12.0                      11.0  ... -0.070628
# 128                       3.0                       1.0  ... -0.033711
# 129                       2.0                       2.0  ...  0.060796
# 130                       1.0                       1.0  ...  0.175337
# 131                      12.0                      11.0  ... -0.062400
# 132                       1.0                       1.0  ...  0.061102
# 133                       7.0                       4.0  ... -0.109259
# 134                       1.0                       1.0  ...  0.095274
# 135                       1.0                       1.0  ... -0.043857
# 136                       1.0                       1.0  ... -0.089518
# 137                       2.0                       1.0  ... -0.006760
# 138                       3.0                       3.0  ...  0.083835
# 139                       4.0                       1.0  ...  0.003298
# 140                       8.0                       8.0  ... -0.073563
# 141                       7.0                       5.0  ... -0.116532
# 142                      12.0                      11.0  ...  0.010979
# 143                       2.0                       2.0  ... -0.029801
# 144                       7.0                       5.0  ... -0.071382
# 145                       1.0                       1.0  ...  0.012260
# 146                       1.0                       1.0  ...  0.090741
# 147                       1.0                       1.0  ... -0.044637
# 148                       1.0                       1.0  ... -0.045009
# 149                       7.0                       3.0  ... -0.225898
# 150                      12.0                       1.0  ...  0.018161
# 151                      14.0                      10.0  ... -0.186846
# 152                      14.0                      10.0  ... -0.014249
#
#           PC9  Beak_PC1  Beak_PC2  Beak_PC3  Beak_PC4       Realm  \
# 0   -0.112178 -0.149743 -0.162164  0.236782  0.150732   Neotropic
# 1    0.046456 -0.538515  0.022452  0.301204 -0.025784   Neotropic
# 2   -0.002128 -0.687390  1.143144  0.216819  0.131604   Neotropic
# 3    0.061365  0.368699 -0.114130  0.255070  0.004245    Nearctic
# 4   -0.111457  0.183448  0.116369  0.121061 -0.032545    Nearctic
# 5    0.009378 -0.863894 -0.031610  0.243015  0.032265   Neotropic
# 6    0.013531  1.071510 -0.444810 -0.067657 -0.074172   Neotropic
# 7    0.021545 -2.070790 -0.585015  0.118502 -0.132901    Nearctic
# 8   -0.013790 -0.806874  1.090724  0.050000  0.161141   Neotropic
# 9   -0.047869 -0.942694 -0.162598  0.010292  0.093823    Nearctic
# 10  -0.050887  0.058572 -0.145850 -0.036950  0.000295    Nearctic
# 11   0.013472  0.430575 -0.556205  0.080614  0.029336    Nearctic
# 12  -0.045727 -1.128931 -0.211658 -0.155380  0.095005    Nearctic
# 13   0.028078 -1.031252 -0.269594 -0.100774  0.042549    Nearctic
# 14  -0.042221  0.054547 -0.372516 -0.096637 -0.006743   Neotropic
# 15   0.012967  0.393342 -0.660959  0.157404  0.032896   Neotropic
# 16   0.081061 -0.738033 -0.186473 -0.094728 -0.047615    Nearctic
# 17  -0.038360  1.302130  0.210778 -0.135645  0.030047    Nearctic
# 18  -0.001014  0.181907  0.316739 -0.067308 -0.034571   Neotropic
# 19  -0.018587  1.805364 -0.189936  0.478773 -0.048400    Nearctic
# 20  -0.117388 -1.458919  0.180152  0.153040  0.121488    Nearctic
# 21  -0.050891 -1.192522 -0.244255  0.341449  0.048122    Nearctic
# 22  -0.150249 -0.669816 -0.154365 -0.051667  0.124670  Palearctic
# 23   0.106896 -0.775888 -0.385085 -0.011878 -0.116015    Nearctic
# 24   0.030402 -1.847291 -0.361823  0.226721 -0.164601   Neotropic
# 25  -0.129243  2.689094 -0.292598  0.066488  0.038383   Neotropic
# 26  -0.036609 -1.212297  0.034688 -0.026126  0.053491    Nearctic
# 27  -0.152757 -0.270881 -0.827347 -0.032034  0.233253    Nearctic
# 28  -0.057317 -0.586968 -0.389985 -0.084503  0.082385    Nearctic
# 29   0.045280  0.579499 -0.612242 -0.044482  0.047441    Nearctic
# ..        ...       ...       ...       ...       ...         ...
# 123 -0.003248  0.015065  0.257783 -0.083623  0.000633   Neotropic
# 124  0.145559  1.101125 -0.369750 -0.231836 -0.133098   Neotropic
# 125  0.036429 -1.046652  0.954788  0.199435  0.160814   Neotropic
# 126 -0.021408 -0.455365 -0.311401 -0.110226  0.161189   Neotropic
# 127  0.010085 -1.122688 -0.145622 -0.068306  0.032320    Nearctic
# 128  0.036810  1.998230 -0.575941 -0.010616 -0.125419    Nearctic
# 129 -0.059855  0.603521  0.475883  0.061839  0.031277    Nearctic
# 130 -0.032975 -0.922377  0.360084 -0.141347 -0.127816    Nearctic
# 131  0.126457 -0.657462 -0.111679  0.340362 -0.099537    Nearctic
# 132 -0.049054  0.997538 -0.260438  0.099057 -0.148697   Neotropic
# 133  0.040774 -1.189136 -0.201041  0.386013 -0.044633  Palearctic
# 134 -0.028284  0.437724  0.864259 -0.143025  0.100952   Neotropic
# 135  0.006031 -1.198755 -0.064441 -0.123941  0.042669    Nearctic
# 136 -0.038147 -0.130160 -0.578034  0.004343  0.094562  Palearctic
# 137 -0.008762  0.981406 -0.037812  0.133244 -0.014767    Nearctic
# 138 -0.084569 -0.115831 -0.723824 -0.165151  0.108877   Neotropic
# 139  0.069679 -0.355750  0.098753  0.240044 -0.033837    Nearctic
# 140 -0.044581 -0.738706 -0.259573 -0.098183  0.056004    Nearctic
# 141 -0.169951  1.344184 -0.004643  0.210984  0.158528  Palearctic
# 142 -0.041475 -1.023333  0.292165 -0.100409  0.076726    Nearctic
# 143 -0.044035 -0.210502  0.083352 -0.027321 -0.013405    Nearctic
# 144  0.071014  1.714963 -0.211904  0.603260 -0.172338    Nearctic
# 145 -0.083386  1.978635 -0.368576 -0.001512  0.028067   Neotropic
# 146 -0.062794  0.075428 -0.760326  0.045340  0.002041    Nearctic
# 147  0.162958  2.707806 -0.045513  0.047754 -0.135083  Palearctic
# 148 -0.062336  1.172711 -0.842640 -0.179956  0.234493   Neotropic
# 149 -0.001699  0.349656 -0.654936  0.026132 -0.065423    Nearctic
# 150  0.060948 -1.236871 -0.096652  0.379866 -0.041239   Neotropic
# 151  0.022250 -0.249738  1.346360  0.091586  0.113709    Nearctic
# 152  0.036047 -1.221765  1.291873 -0.066214  0.128370    Nearctic
#
#      TrophicLevel       TrophicNiche               ForagingNiche
# 0        Omnivore        Invertivore   Invertivore sally surface
# 1       Carnivore        Invertivore                  Generalist
# 2       Herbivore        Nectarivore          Nectarivore aerial
# 3       Carnivore        Invertivore       Invertivore sally air
# 4       Herbivore          Granivore            Granivore ground
# 5       Carnivore        Invertivore                  Generalist
# 6       Carnivore          Vertivore    Vertivore air to surface
# 7       Carnivore        Invertivore          Invertivore aerial
# 8       Herbivore        Nectarivore          Nectarivore aerial
# 9       Carnivore        Invertivore  Invertivore glean arboreal
# 10       Omnivore        Invertivore          Invertivore ground
# 11       Omnivore           Omnivore                         NaN
# 12      Carnivore        Invertivore  Invertivore glean arboreal
# 13      Carnivore        Invertivore  Invertivore glean arboreal
# 14       Omnivore           Omnivore                         NaN
# 15      Carnivore        Invertivore   Invertivore sally surface
# 16      Carnivore        Invertivore  Invertivore glean arboreal
# 17       Omnivore           Omnivore                         NaN
# 18       Omnivore           Omnivore                         NaN
# 19       Omnivore   Aquatic predator                Aquatic dive
# 20      Carnivore        Invertivore  Invertivore glean arboreal
# 21      Carnivore        Invertivore          Invertivore aerial
# 22       Omnivore           Omnivore                         NaN
# 23      Herbivore          Frugivore              Fugivore glean
# 24      Carnivore        Invertivore          Invertivore aerial
# 25      Scavenger          Scavenger            Scavenger ground
# 26      Carnivore        Invertivore  Invertivore glean arboreal
# 27      Herbivore          Granivore                  Generalist
# 28       Omnivore           Omnivore                         NaN
# 29      Carnivore        Invertivore  Invertivore glean arboreal
# ..            ...                ...                         ...
# 123      Omnivore        Invertivore  Invertivore glean arboreal
# 124     Carnivore          Vertivore             Vertivore perch
# 125     Herbivore        Nectarivore          Nectarivore aerial
# 126     Herbivore          Granivore          Granivore arboreal
# 127     Carnivore        Invertivore  Invertivore glean arboreal
# 128     Carnivore          Vertivore             Vertivore perch
# 129      Omnivore        Invertivore          Invertivore ground
# 130     Herbivore          Granivore            Granivore ground
# 131     Carnivore        Invertivore       Invertivore sally air
# 132     Herbivore          Frugivore                  Generalist
# 133     Carnivore        Invertivore          Invertivore aerial
# 134     Carnivore        Invertivore            Invertivore bark
# 135     Carnivore        Invertivore  Invertivore glean arboreal
# 136     Herbivore          Granivore            Granivore ground
# 137      Omnivore           Omnivore                         NaN
# 138     Carnivore        Invertivore    Invertivore sally ground
# 139     Carnivore        Invertivore                  Generalist
# 140      Omnivore           Omnivore                         NaN
# 141     Herbivore  Herbivore aquatic   Herbivore aquatic surface
# 142     Carnivore        Invertivore            Invertivore bark
# 143      Omnivore           Omnivore                         NaN
# 144      Omnivore   Aquatic predator                Aquatic dive
# 145      Omnivore           Omnivore                         NaN
# 146     Herbivore           Omnivore                         NaN
# 147      Omnivore           Omnivore                         NaN
# 148     Herbivore          Frugivore              Fugivore glean
# 149     Carnivore          Vertivore                  Generalist
# 150     Carnivore        Invertivore       Invertivore sally air
# 151     Herbivore        Nectarivore          Nectarivore aerial
# 152     Herbivore        Nectarivore          Nectarivore aerial
#
# [153 rows x 28 columns]

# %% [markdown]
# ## Analysis of category extensions

# %%
# Figure 1 in paper: What categories are give a name
# violin plot (with log frequency of occurrence)
bird_list = list(zapotec_data_only['species'])
freqs = list(zapotec_data_only['freq'])

data_zapotec = [np.log(i) for i in freqs if i >0]
data_all = [np.log(i) for i in bird_counts.values()]

missing_data = []
for birdcount in bird_counts.keys():
	if birdcount not in bird_list:
		missing_data.append(np.log(bird_counts[birdcount]))

# make figure
plt.figure(figsize=(9, 4), dpi=100, facecolor='w', edgecolor='k')
plt.rcParams.update({'font.size': 12})
plt.subplot(1,2,1)

pos = [1,2,3]
plotnames = ('Zapotec','Missing','All OAX')
plt.violinplot([data_zapotec,missing_data,data_all],pos,showmeans=True) 
plt.title('Frequency densities of Zapotec')
plt.xticks(pos,plotnames)
plt.ylabel('Log frequency')



zapotec_masses = {}
for zapotec_bird in basic_levels.keys():
	mass = float(zapotec_data_only[zapotec_data_only['species'] == zapotec_bird]['mass'])  
	if mass > 0:
		zapotec_masses[zapotec_bird] = mass

oax_masses = {}
for oax_bird in bird_counts.keys():
	mass = float(zapotec_data_all[zapotec_data_all['species'] == oax_bird]['mass'])
	if mass > 0:
		oax_masses[oax_bird] = mass
        
        
data_zapotec = [np.log(i) for i in zapotec_masses.values()]
data_all = [np.log(i) for i in oax_masses.values()]

missing_data = []
for birdmass in oax_masses.keys():
	if birdmass not in zapotec_masses.keys():
		missing_data.append(np.log(oax_masses[birdmass]))

plt.subplot(1,2,2)
pos = [1,2,3]
plotnames = ('Zapotec','Missing','All OAX')
plt.violinplot([data_zapotec,missing_data,data_all],pos,showmeans=True) 
plt.title('Mass densities of Zapotec')
plt.xticks(pos,plotnames)
plt.ylabel('Log mass')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Analysis of category size

# %%
#
# Figure 2 in paper: category size plots
#
SSRR_species = {}
xs = []
ys = []
zs = []
for bird_species in bird_list:
    # get basic level

    if float(zapotec_data_only[zapotec_data_only['species'] == bird_species]['freq']) > 0.0:
	    basic_taxon = basic_levels[bird_species]
	    len_unique_species_in_basic = len(list(set(zapotec_data_only[zapotec_data_only['folk_generic'] == basic_taxon]['species'])))
	    SSRR_species[bird_species] = len_unique_species_in_basic
	    xs.append(float(zapotec_data_only[zapotec_data_only['species'] == bird_species]['mass']))
	    ys.append(SSRR_species[bird_species])
	    zs.append(float(zapotec_data_only[zapotec_data_only['species'] == bird_species]['freq']))
    

plt.figure(figsize=(9, 4), dpi=100, facecolor='w', edgecolor='k')
plt.title('Zapotec category organization')

plt.subplot(1,2,1)
ssrrdf = pd.DataFrame(list(zip(np.log(zs),ys)),columns =['log freq','num species'])
sns.regplot(x=ssrrdf["log freq"], y=ssrrdf["num species"])
plt.xlabel('Log frequency')
plt.ylabel('# species per label')
plt.ylim([0.,15.])
plt.yticks((0, 2, 4,6,8,10,12,14))


plt.subplot(1,2,2)
ssrrdf = pd.DataFrame(list(zip(np.log(xs),ys)),columns =['log size','num species'])
sns.regplot(x=ssrrdf["log size"], y=ssrrdf["num species"])
plt.xlabel('Log size')
plt.ylabel('')
plt.ylim([0.,15.])
plt.yticks((0, 2, 4,6,8,10,12,14))
plt.tight_layout()
plt.show()

# %%
slope, intercept, r_value, p_value, std_err = linregress(np.log(zs),np.log(ys))
print("Log Freq\nslope: %f    intercept: %f, p_val: %f" % (slope, intercept,p_value))
print("Category size R-squared: %f" % r_value**2)

slope, intercept, r_value, p_value, std_err = linregress(np.log(xs),np.log(ys))
print("Log Mass\nslope: %f    intercept: %f, p_val: %f" % (slope, intercept,p_value))
print("Category size R-squared: %f" % r_value**2)
# Out:
# Log Freq
# slope: -0.043850    intercept: 1.537600, p_val: 0.431191
# Category size R-squared: 0.004810
# Log Mass
# slope: -0.173697    intercept: 1.910424, p_val: 0.000180
# Category size R-squared: 0.103397

# %% [markdown]
# ## Analysis of category labels
#
# Do frequency and mass influence the form of the name for each species? We focus on names at the folk-specific level and consider the following lexical properties of these names.
#
# ### Name Length
#
# Zipf's Law (1949) is the well-established regularity that word lengths are inversely related to word frequency.

# %%
# relationship between length and frequency
names = list(zapotec_data_only[zapotec_data_only['freq']>0]['folk_specific'])
freqs = list(zapotec_data_only[zapotec_data_only['freq']>0]['freq'])
             
xs1 = [len(i) for i in names]
ys1 = freqs


plt.figure(figsize=(9, 4), dpi=100, facecolor='w', edgecolor='k')
plt.rcParams.update({'font.size': 12})
plt.subplot(1,2,1)

namelen_df = pd.DataFrame(list(zip(np.log(xs1),np.log(ys1))),columns =['log frequency','log name length'])
sns.regplot(x=namelen_df["log frequency"], y=namelen_df["log name length"])

plt.ylabel('Log frequency')
plt.xlabel('Log name length')
plt.title('Name length analysis')


# relationship between length and mass
names = list(zapotec_data_only['folk_specific'])
masses = list(zapotec_data_only['mass'])
             
xs2 = [len(i) for i in names]
ys2 = masses

plt.subplot(1,2,2)
namelen_df = pd.DataFrame(list(zip(np.log(xs2),np.log(ys2))),columns =['log mass','log name length'])
sns.regplot(x=namelen_df["log mass"], y=namelen_df["log name length"])

plt.ylabel('Log mass')
plt.xlabel('Log name length')
plt.title('Name length analysis')

plt.tight_layout()
plt.show()

# %%
slope, intercept, r_value, p_value, std_err = linregress(np.log(xs1),np.log(ys1))
print("Log Freq\nslope: %f    intercept: %f, p_val: %f" % (slope, intercept,p_value))
print("Name length R-squared: %f" % r_value**2)

slope, intercept, r_value, p_value, std_err = linregress(np.log(xs2),np.log(ys2))
print("Log Mass\nslope: %f    intercept: %f, p_val: %f" % (slope, intercept,p_value))
print("Name length R-squared: %f" % r_value**2)
# Out:
# Log Freq
# slope: 0.430153    intercept: 6.134315, p_val: 0.073505
# Name length R-squared: 0.024617
# Log Mass
# slope: -0.668809    intercept: 5.222261, p_val: 0.009767
# Name length R-squared: 0.043394

# %% [markdown]
# ### Compound names
#
# Compound names are notated in Hunn's taxonomy with a dash ('-'), and we explored whether frequency and mass could predict whether the folk-specific name for a species is compound or monomial.

# %%
names = list(zapotec_data_only[zapotec_data_only['freq']>0]['folk_specific'])
freqs = list(zapotec_data_only[zapotec_data_only['freq']>0]['freq'])
monomials = []
compounds = []
for i in range(len(names)):
    if len(names[i].split('-')) > 1:
        if freqs[i] > 0:
            compounds.append(freqs[i])
    else:
        if freqs[i] > 0:
            monomials.append(freqs[i])

plt.figure(figsize=(9, 4), dpi=100, facecolor='w', edgecolor='k')
plt.rcParams.update({'font.size': 12})
plt.subplot(1,2,1)

# violin plot 
data_compounds = [np.log(i) for i in compounds]
data_monomials = [np.log(i) for i in monomials]

pos = [1,2]
plotnames = ('Compounds','Monomials')
plt.violinplot([data_compounds,data_monomials],pos,showmeans=True)
plt.title('Frequency densities of name forms')
plt.xticks(pos,plotnames)
plt.ylabel('Log frequency')

# do the same with mass
mass = list(zapotec_data_only['mass'])

monomials = []
compounds = []
for i in range(len(names)):
    if len(names[i].split('-')) > 1:
        compounds.append(mass[i])
    else:
        monomials.append(mass[i])

# violin plot 
data_compounds = [np.log(i) for i in compounds]
data_monomials = [np.log(i) for i in monomials]

plt.subplot(1,2,2)
pos = [1,2]
plotnames = ('Compounds','Monomials')
plt.violinplot([data_compounds,data_monomials],pos,showmeans=True)
plt.title('Mass densities of name forms')
plt.xticks(pos,plotnames)
plt.ylabel('Log Mass')

plt.tight_layout()
plt.show()

# %%
len(set(zapotec_data_only['folk_generic']))
# Out:
# 68

# %% [markdown]
# ### Prototypes
#
# The literature on folk categorization proposes a link ...

# %%
#
# Figure 3 in paper: Prototype plots
#

plt.rcParams.update({'font.size': 12})

def get_barheights_freq(bar_species,bird_list,df):
	heights = []
	for bird_name in bar_species:
		if bird_name in bird_list:
			heights.append(float(df[df['species'] == bird_name]['freq']))
		else:
			heights.append(0.0)

	return heights


prototypes = ['Cathartes aura','Buteo jamaicensis','Columba livia',
'Bubo virginianus','Thryomanes bewickii',
'Haemorhous mexicanus']


plt.figure(figsize=(12, 6), dpi=100, facecolor='w', edgecolor='k')
plt.subplot(2, 3, 1)

# vultures (3)
bar_species = ['Cathartes aura','Coragyps atratus','Sarcoramphus papa']
bar_labels = ('Turkey','Black','King')
subplot_title = 'Vultures'
heights = get_barheights_freq(bar_species,bird_list,zapotec_data_only)
pos = [1,2,3]
clrs = ['black','lightgrey','lightgrey']
sns.barplot(pos,heights,palette=clrs,edgecolor="Black")
plt.title(subplot_title)
plt.tick_params(labelbottom=False)

plt.subplot(2, 3, 2)
# pigeons (2)
bar_species = ['Columba livia','Patagioenas fasciata']
bar_labels = ('Rock','Band-tailed')
subplot_title = 'Pigeons'
heights = get_barheights_freq(bar_species,bird_list,zapotec_data_only)
pos = [1,2]
clrs = ['black','lightgrey']
sns.barplot(pos,heights,palette=clrs,edgecolor="Black")
plt.title(subplot_title)
plt.tick_params(labelbottom=False)

plt.subplot(2, 3, 3)
# hawks (6)
bar_species = ['Buteo jamaicensis','Accipiter cooperii','Buteo brachyurus','Buteo albonotatus','Falco peregrinus','Accipiter striatus']
bar_labels = ('Red-tailed','Coopers','Short-tailed','Zone-tailed','Peregrine Falcon','Sharp-shinned')
subplot_title = 'Hawks'
heights = get_barheights_freq(bar_species,bird_list,zapotec_data_only)
pos = [1,2,3,4,5,6]
plt.title(subplot_title)
clrs = ['black','lightgrey','lightgrey','lightgrey','lightgrey','lightgrey']
sns.barplot(pos,heights,palette=clrs,edgecolor="Black")
plt.tick_params(labelbottom=False)

plt.subplot(2, 3, 4)
# owls (3)
bar_species = ['Ciccaba virgata','Bubo virginianus','Asio stygius']
bar_labels = ('Mottled','Great Horned','Stygian')
subplot_title = 'Owls'
heights = get_barheights_freq(bar_species,bird_list,zapotec_data_only)
pos = [1,2,3]
clrs = ['lightgrey','black','lightgrey']
sns.barplot(pos,heights,palette=clrs,edgecolor="Black")
plt.title(subplot_title)
plt.tick_params(labelbottom=False)

plt.subplot(2, 3, 5)
# finches (4)
bar_species = ['Haemorhous mexicanus','Icterus wagleri','Pheucticus melanocephalus','Piranga rubra']
bar_labels = ('House','Black-vented','Black-headed','Summer Tanager')
subplot_title = 'Finches'
heights = get_barheights_freq(bar_species,bird_list,zapotec_data_only)
pos = [1,2,3,4]
clrs = ['black','lightgrey','lightgrey','lightgrey']
sns.barplot(pos,heights,palette=clrs,edgecolor="Black")
plt.title(subplot_title)
plt.tick_params(labelbottom=False)


plt.subplot(2, 3, 6)
# wrens (6)
bar_species = ['Thryomanes bewickii','Catherpes mexicanus','Oreothlypis superciliosa','Troglodytes aedon','Henicorhina leucophrys','Salpinctes obsoletus']
bar_labels = ('Bewicks','Canyon','Crescent-chested','Brown-throated','Gray-breasted','Rock')
subplot_title = 'Wrens'
heights = get_barheights_freq(bar_species,bird_list,zapotec_data_only)
pos = [1,2,3,4,5,6]
clrs = ['black','lightgrey','lightgrey','lightgrey','lightgrey','lightgrey']
sns.barplot(pos,heights,palette=clrs,edgecolor="Black")
plt.title(subplot_title)

plt.tick_params(labelbottom=False)
plt.tight_layout()
plt.show()
